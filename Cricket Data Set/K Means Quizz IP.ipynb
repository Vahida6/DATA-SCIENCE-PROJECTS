# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("C://Users//ysadmin//Desktop//Live_20210128.csv")
df.sample(2)
# Out:
#       status_id status_type  status_published  num_reactions  num_comments  \
# 2143       2144       photo  10/13/2012 11:49             16             7
# 4489       4490       video     6/7/2018 6:35           1360          1358
#
#       num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  \
# 2143           0         16          0         0          0         0
# 4489         597        978        278        98          5         0
#
#       num_angrys  Column1  Column2  Column3  Column4
# 2143           0      NaN      NaN      NaN      NaN
# 4489           1      NaN      NaN      NaN      NaN

# %%
df.Column1.unique()
# Out:
# array([nan])

# %%
df=df.drop(columns={'Column4'})

# %%
df.sample(1)
# Out:
#       status_id status_type status_published  num_reactions  num_comments  \
# 5092       5093       photo   5/24/2018 2:14             21             1
#
#       num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  \
# 5092           0         21          0         0          0         0
#
#       num_angrys
# 5092           0

# %%
df.status_id.value_counts()
# Out:
# 1       1
# 4696    1
# 4707    1
# 4706    1
# 4705    1
#        ..
# 2348    1
# 2347    1
# 2346    1
# 2345    1
# 7050    1
# Name: status_id, Length: 7050, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         7050 non-null   int64
#  1   status_type       7050 non-null   object
#  2   status_published  7050 non-null   object
#  3   num_reactions     7050 non-null   int64
#  4   num_comments      7050 non-null   int64
#  5   num_shares        7050 non-null   int64
#  6   num_likes         7050 non-null   int64
#  7   num_loves         7050 non-null   int64
#  8   num_wows          7050 non-null   int64
#  9   num_hahas         7050 non-null   int64
#  10  num_sads          7050 non-null   int64
#  11  num_angrys        7050 non-null   int64
# dtypes: int64(10), object(2)
# memory usage: 661.1+ KB

# %%
df.describe().T
# Out:
#                 count         mean          std  min      25%     50%  \
# status_id      7050.0  3525.500000  2035.304031  1.0  1763.25  3525.5
# num_reactions  7050.0   230.117163   462.625309  0.0    17.00    59.5
# num_comments   7050.0   224.356028   889.636820  0.0     0.00     4.0
# num_shares     7050.0    40.022553   131.599965  0.0     0.00     0.0
# num_likes      7050.0   215.043121   449.472357  0.0    17.00    58.0
# num_loves      7050.0    12.728652    39.972930  0.0     0.00     0.0
# num_wows       7050.0     1.289362     8.719650  0.0     0.00     0.0
# num_hahas      7050.0     0.696454     3.957183  0.0     0.00     0.0
# num_sads       7050.0     0.243688     1.597156  0.0     0.00     0.0
# num_angrys     7050.0     0.113191     0.726812  0.0     0.00     0.0
#
#                    75%      max
# status_id      5287.75   7050.0
# num_reactions   219.00   4710.0
# num_comments     23.00  20990.0
# num_shares        4.00   3424.0
# ...

# %%
df.columns
# Out:
# Index(['status_id', 'status_type', 'status_published', 'num_reactions',
#        'num_comments', 'num_shares', 'num_likes', 'num_loves', 'num_wows',
#        'num_hahas', 'num_sads', 'num_angrys'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# status_id           0
# status_type         0
# status_published    0
# num_reactions       0
# num_comments        0
# num_shares          0
# num_likes           0
# num_loves           0
# num_wows            0
# num_hahas           0
# num_sads            0
# num_angrys          0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [status_id, status_type, status_published, num_reactions, num_comments, num_shares, num_likes, num_loves, num_wows, num_hahas, num_sads, num_angrys]
# Index: []

# %%
data1=df[df['status_published']== '4/19/2018 22:26']
data1
# Out:
#       status_id status_type status_published  num_reactions  num_comments  \
# 4592       4593       photo  4/19/2018 22:26            383             5
#
#       num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  \
# 4592           6        379          2         2          0         0
#
#       num_angrys
# 4592           0

# %%
data2=df[df['status_published']== '7/15/2017 10:52']
data2
# Out:
#       status_id status_type status_published  num_reactions  num_comments  \
# 6977       6978       video  7/15/2017 10:52            253          4432
#
#       num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  \
# 6977         167        209         29         5          5         5
#
#       num_angrys
# 6977           0

# %%
df.status_type.value_counts()
# Out:
# photo     4288
# video     2334
# status     365
# link        63
# Name: status_type, dtype: int64

# %%
df.head(10)
# Out:
#    status_id status_type status_published  num_reactions  num_comments  \
# 0          1       video   4/22/2018 6:00            529           512
# 1          2       photo  4/21/2018 22:45            150             0
# 2          3       video   4/21/2018 6:17            227           236
# 3          4       photo   4/21/2018 2:29            111             0
# 4          5       photo   4/18/2018 3:22            213             0
# 5          6       photo   4/18/2018 2:14            217             6
# 6          7       video   4/18/2018 0:24            503           614
# 7          8       video   4/17/2018 7:42            295           453
# 8          9       photo   4/17/2018 3:33            203             1
# 9         10       photo   4/11/2018 4:53            170             9
#
#    num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0         262        432         92         3          1         1           0
# ...

# %%
df_drop = df.copy()
status_published= df_drop.pop('status_published')

# %%
status_type=df_drop.pop('status_type')

# %%
df.iloc[:,3:12]
# Out:
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0               529           512         262        432         92         3
# 1               150             0           0        150          0         0
# 2               227           236          57        204         21         1
# 3               111             0           0        111          0         0
# 4               213             0           0        204          9         0
# ...             ...           ...         ...        ...        ...       ...
# 7045             89             0           0         89          0         0
# 7046             16             0           0         14          1         0
# 7047              2             0           0          1          1         0
# 7048            351            12          22        349          2         0
# 7049             17             0           0         17          0         0
#
# ...

# %%
df_drop.head()
# Out:
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0            529           512         262        432         92         3
# 1            150             0           0        150          0         0
# 2            227           236          57        204         21         1
# 3            111             0           0        111          0         0
# 4            213             0           0        204          9         0
#
#    num_hahas  num_sads  num_angrys
# 0          1         1           0
# 1          0         0           0
# 2          1         0           0
# 3          0         0           0
# 4          0         0           0

# %%
status_id=df_drop.pop('status_id')

# %%
import sklearn
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_drop)
df_scaled
# Out:
# array([[ 0.64610394,  0.32335035,  1.6868788 , ...,  0.07671305,
#          0.47357035, -0.15574803],
#        [-0.17319166, -0.25220622, -0.3041444 , ..., -0.17600986,
#         -0.152587  , -0.15574803],
#        [-0.00673846,  0.01308938,  0.12901714, ...,  0.07671305,
#         -0.152587  , -0.15574803],
#        ...,
#        [-0.49312768, -0.25220622, -0.3041444 , ..., -0.17600986,
#         -0.152587  , -0.15574803],
#        [ 0.26131603, -0.23871662, -0.13695924, ..., -0.17600986,
#         -0.152587  , -0.15574803],
#        [-0.46070173, -0.25220622, -0.3041444 , ..., -0.17600986,
#         -0.152587  , -0.15574803]])

# %%
df_df1 = pd.DataFrame(df_scaled, columns = ['num_reactions','num_comments','num_shares','num_likes','num_loves','num_wows','num_hahas','num_sads','num_angrys'])
df_df1.head()
# Out:
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0       0.646104      0.323350    1.686879   0.482727   1.983266  0.196196
# 1      -0.173192     -0.252206   -0.304144  -0.144720  -0.318454 -0.147879
# 2      -0.006738      0.013089    0.129017  -0.024571   0.206938 -0.033187
# 3      -0.257499     -0.252206   -0.304144  -0.231495  -0.318454 -0.147879
# 4      -0.037003     -0.252206   -0.304144  -0.024571  -0.093286 -0.147879
#
#    num_hahas  num_sads  num_angrys
# 0   0.076713  0.473570   -0.155748
# 1  -0.176010 -0.152587   -0.155748
# 2   0.076713 -0.152587   -0.155748
# 3  -0.176010 -0.152587   -0.155748
# 4  -0.176010 -0.152587   -0.155748

# %% [markdown]
# Iplementing Clustering

# %%
from sklearn.cluster import KMeans

# %%
clusters=list(range(1,9))
wcss = []
for num_clusters in clusters:
    model_clus = KMeans(n_clusters = num_clusters)
    model_clus.fit(df_df1)
    wcss.append(model_clus.inertia_)

plt.plot(clusters,wcss);

# %%
cluster = KMeans(n_clusters=4)
cluster.fit(df_df1)
# Out:
# KMeans(n_clusters=4)

# %%
colour=['red','blue','green','yellow','cyan'] 
n=0  
for i in range(0,len(colour)):  
    plt.scatter(X[df['Clusters(5)']==i],Y[df['Clusters(5)']==i],s=10,c=colour[i]) 
    plt.scatter(k.cluster_centers_[:,0] ,k.cluster_centers_[:,1], color='black')
    colour=['red','blue','green','yellow','cyan'] 
    n=0  
    for i in range(0,len(colour)):  
        plt.scatter(X[df['Clusters(5)']==i],Y[df['Clusters(5)']==i],s=10,c=colour[i]) 
        plt.scatter(k.cluster_centers_[:,0] ,k.cluster_centers_[:,1], color='black')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [47], in <cell line: 3>()
#       2 n=0
#       3 for i in range(0,len(colour)):
# ----> 4     plt.scatter(X[df['Clusters(5)']==i],Y[df['Clusters(5)']==i],s=10,c=colour[i])
#       5     plt.scatter(k.cluster_centers_[:,0] ,k.cluster_centers_[:,1], color='black')
#       6     colour=['red','blue','green','yellow','cyan']
#
# NameError: name 'X' is not defined

# %%
kmeans.inertia_
# Out:
# 32469.79136230988

# %%
kmeans = KMeans(n_clusters=4, init='k-means++')

# fitting the k means algorithm on scaled data
kmeans.fit(df_df1)
# Out:
# KMeans(n_clusters=4)

# %%
# fitting multiple k-means algorithms and storing the values in an empty list
SSE = []
for cluster in range(1,10):
    kmeans = KMeans(n_jobs = -1, n_clusters = cluster, init='k-means++')
    kmeans.fit(df_df1)
    SSE.append(kmeans.inertia_)

# converting the results into a dataframe and plotting them
frame = pd.DataFrame({'Cluster':range(1,20), 'SSE':SSE})
plt.figure(figsize=(12,6))
plt.plot(frame['Cluster'], frame['SSE'], marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [51], in <cell line: 3>()
#       2 SSE = []
#       3 for cluster in range(1,10):
# ----> 4     kmeans = KMeans(n_jobs = -1, n_clusters = cluster, init='k-means++')
#       5     kmeans.fit(df_df1)
#       6     SSE.append(kmeans.inertia_)
#
# TypeError: __init__() got an unexpected keyword argument 'n_jobs'
